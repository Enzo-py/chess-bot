# %%
import chess
from models.cnn.cnn_score import CNNScore
from models.deep_engine import *

from src.chess.game_generator import GameGenerator
from src.chess.game import Game
from src.chess.puzzle import Puzzle
from src.chess.loader import Loader

# %%
print("Setup environment...")
model = CNNScore()
model.load("models/saves/CNNScore-V0.auto-save.pth")

nb_batches = 2
batch_size = 8
epochs = 20
test_size = 128

ld_games = Loader(window=nb_batches, epochs_per_window=3, min_elo=1800).load(
    "data/lichess_db_standard_rated_2013-04.pgn.zst", 
    Game, 
    chunksize=batch_size
)

ld_puzzles = Loader(window=nb_batches, epochs_per_window=3).load(
    "data/lichess_db_puzzle.csv.zst", 
    Puzzle, 
    chunksize=batch_size
)

# ld_puzzles.skip(20 * 10)
# ld_games.skip(20 * 10)
# Out:
# Setup environment...

# %%
with model | generative_head | with_prints | auto_save as env:
    x = env.train(
        epochs=epochs, 
        batch_size=batch_size, 
        loader=ld_games | ld_puzzles
    )

    env.test(loader=ld_games | ld_puzzles)

    env.plot(x)
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────╮
# | 🔄 TRAINING SESSION Engine: <CNNScore>                                         |
# | On <None> with <generative> head                                               |
# |────────────────────────────────────────────────────────────────────────────────|
# | >> Start training for 20 epochs                                                |
# |  > Updating data                                                               |
# | : 100%|███████████████████████████████████████| 32/32 [00:00<00:00, 6560.65it/s]
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 176.51it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:08<00:00, 11.79it/s]
# |   [1/20] Loss: 12.41, Best Move Loss: 12.41, Contrastive loss 0.00             |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:08<00:00, 12.63it/s]
# |   [2/20] Loss: 5.85, Best Move Loss: 5.85, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:08<00:00, 12.86it/s]
# |   [3/20] Loss: 4.98, Best Move Loss: 4.98, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 85.93it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 148/148 [00:11<00:00, 12.91it/s]
# |   [4/20] Loss: 6.68, Best Move Loss: 6.68, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 148/148 [00:11<00:00, 12.88it/s]
# |   [5/20] Loss: 5.15, Best Move Loss: 5.15, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 148/148 [00:11<00:00, 12.78it/s]
# |   [6/20] Loss: 4.00, Best Move Loss: 4.00, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 187.06it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 108/108 [00:08<00:00, 12.59it/s]
# |   [7/20] Loss: 5.82, Best Move Loss: 5.82, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 108/108 [00:08<00:00, 12.58it/s]
# |   [8/20] Loss: 4.11, Best Move Loss: 4.11, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 108/108 [00:08<00:00, 12.58it/s]
# |   [9/20] Loss: 2.81, Best Move Loss: 2.81, Contrastive loss 0.00               |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 179.92it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 109/109 [00:08<00:00, 12.70it/s]
# |   [10/20] Loss: 5.50, Best Move Loss: 5.50, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 109/109 [00:08<00:00, 12.59it/s]
# |   [11/20] Loss: 3.55, Best Move Loss: 3.55, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 109/109 [00:08<00:00, 12.69it/s]
# |   [12/20] Loss: 2.18, Best Move Loss: 2.18, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 104.86it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 100/100 [00:08<00:00, 12.33it/s]
# |   [13/20] Loss: 5.22, Best Move Loss: 5.22, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 100/100 [00:08<00:00, 12.33it/s]
# |   [14/20] Loss: 3.13, Best Move Loss: 3.13, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 100/100 [00:08<00:00, 12.31it/s]
# |   [15/20] Loss: 1.69, Best Move Loss: 1.69, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 190.62it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 102/102 [00:08<00:00, 12.59it/s]
# |   [16/20] Loss: 5.25, Best Move Loss: 5.25, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 102/102 [00:08<00:00, 12.57it/s]
# |   [17/20] Loss: 3.07, Best Move Loss: 3.07, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 102/102 [00:08<00:00, 12.65it/s]
# |   [18/20] Loss: 1.62, Best Move Loss: 1.62, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 99.69it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 118/118 [00:09<00:00, 12.81it/s]
# |   [19/20] Loss: 5.17, Best Move Loss: 5.17, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 118/118 [00:09<00:00, 12.84it/s]
# |   [20/20] Loss: 2.95, Best Move Loss: 2.95, Contrastive loss 0.00              |
# |   Legal Loss: 0.00                                                             |
# |                                                                                |
# | >> Start testing                                                               |
# |  > Updating data                                                               |
# | : 100%|███████████████████████████████████████| 32/32 [00:00<00:00, 8366.65it/s]
# |                                                                                |
# |   Accuracy: 0.01                                                               |
# |────────────────────────────────────────────────────────────────────────────────|
# | ✅ Training session completed                                                  |
# ╰────────────────────────────────────────────────────────────────────────────────╯

# %%
with model | board_evaluation_head | with_prints | auto_save as env:
    X = env.train(
        epochs=epochs, 
        batch_size=batch_size, 
        loader=ld_games | ld_puzzles
    )

    env.test(loader=ld_games | ld_puzzles)

    env.plot(X)
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────╮
# | 🔄 TRAINING SESSION Engine: <CNNScore>                                         |
# | On <None> with <board_evaluation> head                                         |
# |────────────────────────────────────────────────────────────────────────────────|
# | >> Start training for 20 epochs                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 118.08it/s]
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 99.50it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 118/118 [00:03<00:00, 31.95it/s]
# |   [1/20] Loss: 0.39, Contrastive Loss: 1.71,                                   |
# |   Classification Loss: 0.13                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 118/118 [00:03<00:00, 32.31it/s]
# |   [2/20] Loss: 0.26, Contrastive Loss: 1.37,                                   |
# |   Classification Loss: 0.06                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 118/118 [00:03<00:00, 32.35it/s]
# |   [3/20] Loss: 0.24, Contrastive Loss: 1.31,                                   |
# |   Classification Loss: 0.05                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 190.97it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:03<00:00, 32.38it/s]
# |   [4/20] Loss: 0.46, Contrastive Loss: 1.80,                                   |
# |   Classification Loss: 0.19                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:03<00:00, 31.70it/s]
# |   [5/20] Loss: 0.32, Contrastive Loss: 1.43,                                   |
# |   Classification Loss: 0.10                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 106/106 [00:03<00:00, 31.51it/s]
# |   [6/20] Loss: 0.26, Contrastive Loss: 1.36,                                   |
# |   Classification Loss: 0.06                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 182.12it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 107/107 [00:03<00:00, 31.54it/s]
# |   [7/20] Loss: 0.35, Contrastive Loss: 1.56,                                   |
# |   Classification Loss: 0.12                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 107/107 [00:03<00:00, 30.80it/s]
# |   [8/20] Loss: 0.25, Contrastive Loss: 1.31,                                   |
# |   Classification Loss: 0.06                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 107/107 [00:03<00:00, 31.80it/s]
# |   [9/20] Loss: 0.23, Contrastive Loss: 1.25,                                   |
# |   Classification Loss: 0.05                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 134.89it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 135/135 [00:04<00:00, 31.35it/s]
# |   [10/20] Loss: 0.42, Contrastive Loss: 1.65,                                  |
# |   Classification Loss: 0.17                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 135/135 [00:04<00:00, 30.70it/s]
# |   [11/20] Loss: 0.27, Contrastive Loss: 1.27,                                  |
# |   Classification Loss: 0.08                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 135/135 [00:04<00:00, 31.37it/s]
# |   [12/20] Loss: 0.24, Contrastive Loss: 1.29,                                  |
# |   Classification Loss: 0.04                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 135.64it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 136/136 [00:04<00:00, 30.62it/s]
# |   [13/20] Loss: 0.42, Contrastive Loss: 1.70,                                  |
# |   Classification Loss: 0.17                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 136/136 [00:04<00:00, 30.88it/s]
# |   [14/20] Loss: 0.28, Contrastive Loss: 1.39,                                  |
# |   Classification Loss: 0.07                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 136/136 [00:04<00:00, 31.09it/s]
# |   [15/20] Loss: 0.23, Contrastive Loss: 1.25,                                  |
# |   Classification Loss: 0.04                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 83.72it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 143/143 [00:04<00:00, 30.64it/s]
# |   [16/20] Loss: 0.42, Contrastive Loss: 1.52,                                  |
# |   Classification Loss: 0.20                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 143/143 [00:04<00:00, 30.50it/s]
# |   [17/20] Loss: 0.30, Contrastive Loss: 1.35,                                  |
# |   Classification Loss: 0.09                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 143/143 [00:04<00:00, 30.75it/s]
# |   [18/20] Loss: 0.26, Contrastive Loss: 1.36,                                  |
# |   Classification Loss: 0.06                                                    |
# |                                                                                |
# |  > Updating data                                                               |
# | : 100%|████████████████████████████████████████| 32/32 [00:00<00:00, 145.38it/s]
# |                                                                                |
# | : 100%|███████████████████████████████████████| 127/127 [00:04<00:00, 30.73it/s]
# |   [19/20] Loss: 0.38, Contrastive Loss: 1.54,                                  |
# |   Classification Loss: 0.14                                                    |
# |                                                                                |
# | : 100%|███████████████████████████████████████| 127/127 [00:04<00:00, 30.65it/s]
# |   [20/20] Loss: 0.27, Contrastive Loss: 1.34,                                  |
# |   Classification Loss: 0.07                                                    |
# |                                                                                |
# | >> Start testing                                                               |
# |  > Updating data                                                               |
# | : 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 89.98it/s]
# |                                                                                |
# |   Accuracy: 0.49                                                               |
# |────────────────────────────────────────────────────────────────────────────────|
# | ✅ Training session completed                                                  |
# ╰────────────────────────────────────────────────────────────────────────────────╯
